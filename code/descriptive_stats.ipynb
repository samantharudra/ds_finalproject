# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Samantha\anaconda_work\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\Samantha\anaconda_work\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
# Import dataset 

df = pd.read_csv("../data/cleaned data/merged_data.csv")
df = df.dropna()
df.head()
# Out:
#                            District Name                   DistrictType  \
# 2       ABINGTON HEIGHTS SCHOOL DISTRICT  Regular local school district
# 3               ABINGTON SCHOOL DISTRICT  Regular local school district
# 9   ALBERT GALLATIN AREA SCHOOL DISTRICT  Regular local school district
# 10             ALIQUIPPA SCHOOL DISTRICT  Regular local school district
# 11      ALLEGHENY VALLEY SCHOOL DISTRICT  Regular local school district
#
#     Virtual  Hybrid  In_Person  mean_proficient_english_2019  \
# 2       1.0     8.0        0.0                     51.080000
# 3       2.0     7.0        0.0                     47.787500
# 9       2.0     7.0        0.0                     40.185714
# 10      6.0     2.0        1.0                     20.800000
# 11      0.0     9.0        0.0                     43.200000
#
#     mean_proficient_math_2019  mean_proficient_english_2022  \
# 2                   37.460000                     46.000000
# ...

# %%
# Get descriptive statistics for dataset

descriptive_stats = df.describe()

# %%
descriptive_stats.head()
# Out:
#           Virtual      Hybrid   In_Person  mean_proficient_english_2019  \
# count  432.000000  432.000000  432.000000                    432.000000
# mean     1.034722    5.631944    2.076389                     45.616979
# std      1.792275    2.978842    2.714778                      5.988525
# min      0.000000    0.000000    0.000000                     14.200000
# 25%      0.000000    4.000000    0.000000                     43.921667
#
#        mean_proficient_math_2019  mean_proficient_english_2022  \
# count                 432.000000                    432.000000
# mean                   28.651119                     41.004377
# std                     6.195308                      6.524887
# min                     2.750000                     12.100000
# 25%                    25.950000                     38.787500
#
#        mean_proficient_math_2022  Unnamed: 0  NumberofSchools  \
# count                 432.000000  432.000000       432.000000
# ...

# %%
# Export to .csv

descriptive_stats.to_csv('../data/cleaned data/descriptive_stats.csv', index=True)
